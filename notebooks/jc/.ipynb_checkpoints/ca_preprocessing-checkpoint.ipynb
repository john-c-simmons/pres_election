# %%
import numpy as np 
import pandas as pd
df = pd.read_csv('../../data/california_2015.csv')
dfcensus = pd.read_csv('../../data/2015_California_Census_Data.csv')
df2 = pd.read_csv('../../data/california_2018.csv')
counties = pd.read_csv('../../data/ca_counties.csv', names = ['fips', 'name'])
fips_dict = counties.set_index('name')['fips'].to_dict()
df['county'] = df['county'].str.title()
df['fips'] = df['county'].map(fips_dict)
df2['county'] = df2['county'].str.title()
df2['fips'] = df2['county'].map(fips_dict)

# %%
dfcensus
# Out:
#     Unnamed: 0  YEAR  STATEFIP     avg_inc  avg_age  avg_educ  avg_educd  \
# 0           37  2015         6   527508.44    50.78      7.28      75.04
# 1           73  2015         6   765623.18    49.56      7.63      78.59
# 2           85  2015         6   615511.78    49.99      8.28      85.24
# 3            1  2015         6   500963.46    49.29      8.08      83.08
# 4           29  2015         6  1244773.84    45.40      5.84      60.66
# 5            0  2015         6   980584.96    53.42      7.07      72.98
# 6           77  2015         6   479714.11    49.58      6.96      71.74
# 7           67  2015         6   543471.23    47.84      7.43      76.39
# 8           65  2015         6   446909.92    51.03      6.85      70.86
# 9           13  2015         6   387181.29    54.22      8.12      83.42
# 10          83  2015         6  1592139.07    51.13      7.79      80.26
# 11          75  2015         6   792750.86    49.00      8.38      85.97
# ...

# %%
df.columns
# Out:
# Index(['school_code', 'county', 'public/private', 'district', 'city',
#        'school_name', 'enrollment', 'vaccinated_n', 'vaccinated_perc',
#        'temp_unvax_n', 'temp_unvax_perc', 'perm_med_exemp_n',
#        'perm_med_exemp_perc', 'pbe_n', 'pbe_perc', 'hcp_counceled_pbe_n',
#        'hcp_counceled_pbe_perc', 'religious_exemp_n', 'religious_exemp_perc',
#        'over_due_n', 'over_due_perc', 'five_dose_DTP_n', 'five_dose_DTP_perc',
#        'polio_n', 'polio_perc', 'mmr_n', 'mmr_perc', 'hepb_n', 'hepb_perc',
#        'varicell_n', 'varicella_perc', 'reported', 'year', 'state', 'fips'],
#       dtype='object')

# %%
county_list = df.fips.unique().tolist()

# %%
def vax_percentage(df):
    percentage_list = []
    for fip in county_list:
        c_df = df[df.fips == fip]
        c_df['vaccinated_n'] = c_df['enrollment']* c_df['vaccinated_perc']
        enrollment = c_df['enrollment'].sum()
        percentage_vaccinated = (c_df['vaccinated_n'].sum()) / enrollment
        percentage_list.append(percentage_vaccinated)
    return percentage_list

# %%
percentage_vaccinated = vax_percentage(df)
# Out:
# <ipython-input-34-20bb1b4fa6f6>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_df['vaccinated_n'] = c_df['enrollment']* c_df['vaccinated_perc']
# <ipython-input-34-20bb1b4fa6f6>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_df['vaccinated_n'] = c_df['enrollment']* c_df['vaccinated_perc']
# <ipython-input-34-20bb1b4fa6f6>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
ca_list = pd.DataFrame({'county': county_list, 'percentage_vaccinated': percentage_vaccinated})

# %%
ca_list_dict = dict(zip(ca_list.county,ca_list.percentage_vaccinated))

# %%
dfcensus['percentage_vaccinated'] = dfcensus['FIP'].map(ca_list_dict)

# %%
dfcensus = dfcensus.drop(['Unnamed: 0', 'STATEFIP'], axis=1)

# %%
dfcensus
# Out:
#     YEAR     avg_inc  avg_age  avg_educ  avg_educd   sex  insurance  \
# 0   2015   527508.44    50.78      7.28      75.04  0.49       0.90
# 1   2015   765623.18    49.56      7.63      78.59  0.49       0.91
# 2   2015   615511.78    49.99      8.28      85.24  0.46       0.96
# 3   2015   500963.46    49.29      8.08      83.08  0.47       0.93
# 4   2015  1244773.84    45.40      5.84      60.66  0.51       0.86
# 5   2015   980584.96    53.42      7.07      72.98  0.49       0.90
# 6   2015   479714.11    49.58      6.96      71.74  0.47       0.93
# 7   2015   543471.23    47.84      7.43      76.39  0.51       0.95
# 8   2015   446909.92    51.03      6.85      70.86  0.51       0.86
# 9   2015   387181.29    54.22      8.12      83.42  0.57       0.96
# 10  2015  1592139.07    51.13      7.79      80.26  0.50       0.87
# 11  2015   792750.86    49.00      8.38      85.97  0.43       0.96
# 12  2015   541479.92    48.67      6.63      68.64  0.49       0.89
# ...
