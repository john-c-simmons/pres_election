# %%
import numpy as np 
import pandas as pd
df = pd.read_csv('../../data/florida_2019.csv')
counties = pd.read_csv('../../data/fl_counties.csv', names = ['fips', 'name'])
fips_dict = counties.set_index('name')['fips'].to_dict()
df['county'] = df['county'].map(lambda x: x.rstrip('3'))
df['fips'] = df['county'].map(fips_dict)

# %%
df.iloc[67, 15]=12109
df.iloc[68, 15]=00000
df.iloc[69, 15]=12111
df.iloc[70, 15]=12099
df.iloc[71, 15]=12073
df.iloc[72, 15]=12011
df.iloc[73, 15]=12073
df.iloc[74, 15]=12001
df.iloc[75, 15]=00000

# %%
df
# Out:
#                    county num_schools num_students full_immunization_count  \
# 0                 Alachua          59        2,682                   2,535
# 1                   Baker           5          417                     401
# 2                     Bay          33        1,972                   1,885
# 3                Bradford          10          312                     297
# 4                 Brevard         115        5,804                   5,527
# ..                    ...         ...          ...                     ...
# 71     FSU Lab Sch (Leon)           1          114                     114
# 72  FSU Lab Sch (Broward)           1           96                      88
# 73    FAMU Lab Sch (Leon)           1           40                      37
# 74   UF Lab Sch (Alachua)           1           49                      46
# 75              Statewide       4,245      228,298                 213,455
#
#     full_immunization_perc temp_medical_exemp_count  temp_medical_exemp_perc  \
# 0                     94.5                       58                      2.2
# 1                     96.2                        3                      0.7
# 2                     95.6                       39                      2.0
# 3                     95.2                        7                      2.2
# 4                     95.2                       50                      0.9
# ..                     ...                      ...                      ...
# 71                   100.0                        0                      0.0
# 72                    91.7                        6                      6.3
# 73                    92.5                        2                      5.0
# 74                    93.9                        1                      2.0
# 75                    93.5                    6,380                      2.8
#
#     perm_medical_exemp_count  perm_medical_exemp_perc religious_exemp_count  \
# 0                          1                      0.0                    87
# 1                          0                      0.0                    13
# 2                          3                      0.2                    42
# 3                          0                      0.0                     8
# 4                         15                      0.3                   208
# ..                       ...                      ...                   ...
# 71                         0                      0.0                     0
# 72                         0                      0.0                     2
# 73                         0                      0.0                     1
# 74                         0                      0.0                     2
# 75                       855                      0.4                 6,903
#
#     religious_exemp_perc  30_day_exemp_count  30_day_exemp_perc  year state  \
# 0                    3.2                   1                0.0  2019    FL
# 1                    3.1                   0                0.0  2019    FL
# 2                    2.1                   2                0.1  2019    FL
# 3                    2.6                   0                0.0  2019    FL
# 4                    3.6                   4                0.1  2019    FL
# ..                   ...                 ...                ...   ...   ...
# 71                   0.0                   0                0.0  2019    FL
# 72                   2.1                   0                0.0  2019    FL
# 73                   2.5                   0                0.0  2019    FL
# 74                   4.1                   0                0.0  2019    FL
# 75                   3.0                 357                0.2  2019    FL
#
#        fips
# 0   12001.0
# 1   12003.0
# 2   12005.0
# 3   12007.0
# 4   12009.0
# ..      ...
# 71  12073.0
# 72  12011.0
# 73  12073.0
# 74  12001.0
# 75      0.0
#
# [76 rows x 16 columns]
