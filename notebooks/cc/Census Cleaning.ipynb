# %%
original_columns = {"C24050_002E": "Total Agriculture, forestry, fishing and hunting, and mining", 
    "C24050_003E": "Total Construction", 
    "C24050_004E": "Total Manufacturing", 
    "C24050_005E": "Total Wholesale trade", 
    "C24050_006E": "Total Retail trade", 
    "C24050_007E": "Total Transportation and warehousing, and utilities", 
    "C24050_008E": "Total Information", 
    "C24050_009E": "Total Finance and insurance, and real estate, and rental and leasing", 
    "C24050_010E": "Total Professional, scientific, and management, and administrative, and waste management services", 
    "C24050_011E": "Total Educational services, and health care and social assistance", 
    "C24050_012E": "Total Arts, entertainment, and recreation, and accommodation and food services", 
    "C24050_013E": "Total Other services, except public administration", 
    "C24050_014E": "Total Public administration", 
    "C24050_015E": "Total Management, business, science, and arts occupations", 
    "C24050_029E": "Total Service occupations", 
    "C24050_043E": "Total Sales and office occupations", 
    "C24050_057E": "Total Natural resources, construction, and maintenance occupations", 
    "C24050_071E": "Total Production, transportation, and material moving occupations", 
    "C02003_002E": "Population of one race Total",
    "C02003_003E": "Population of one race White", 
    "C02003_004E": "Population of one race Black or African American", 
    "C02003_005E": "Population of one race American Indian and Alaska Native", 
    "C02003_006E": "Population of one race Asian alone", 
    "C02003_007E": "Population of one race Native Hawaiian and Other Pacific Islander",
    "C02003_008E": "Population of one race Some other race", 
    "B01002_001E": "Median age: Total", 
    "B15003_001E": "EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER: TOTAL", 
    "B15003_002E": "EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER No schooling completed",
    "B15003_003E": "EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER Nursery school",
    "B15003_004E": "EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER Kindergarten",
    "B15003_005E": "EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER 1st grade",
     "B15003_006E": "EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER 2nd grade",
     "B15003_007E": "EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER 3rd grade",
     "B15003_008E": "EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER 4th grade",
     "B15003_009E": "EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER 5th grade",
     "B15003_010E": "EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER 6th grade",
     "B15003_011E": "EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER 7th grade",
     "B15003_012E": "EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER 8th grade",
     "B15003_013E": "EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER 9th grade",
     "B15003_014E": "EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER 10th grade",
     "B15003_015E": "EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER 11th grade",
     "B15003_016E": "EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER 12th grade, no diploma",
    "B19326_001E": "Median income in the past 12 months (in prior year inflation-adjusted dollars)!!Total (dollars)", 
 "B23025_005E": "UNEMPLOYED STATUS FOR THE POPULATION 16 YEARS AND OVER",
 "B23025_003E":  "In labor force: Civilian labor force",
 "B27010_017E": "Under 19 years:!!No health insurance coverage",
 "B27010_033E": "19 to 34 years:!!No health insurance coverage",
 "B27010_050E": "35 to 64 years:!!No health insurance coverage",
 "B27010_001E": "health insurance: total",
 "B27010_066E": "65 years and over:!!No health insurance coverage",
    "B01003_001E": "TOTAL POPULATION Estimate!!Total"}

# %%
import pandas as pd

# %%
df2015 = pd.read_csv('../../cece_data/county_cece_data_2015.csv')

# %%
df2015.head()
# Out:
#                                           Unnamed: 0  C24050_002E  \
# 0  Alameda County, California: Summary level: 050...         3308
# 1  Alpine County, California: Summary level: 050,...            0
# 2  Amador County, California: Summary level: 050,...          195
# 3  Butte County, California: Summary level: 050, ...         3249
# 4  Calaveras County, California: Summary level: 0...          496
#
#    C24050_003E  C24050_004E  C24050_005E  C24050_006E  C24050_007E  \
# 0        39861        80961        20969        75187        39042
# 1           24           15            0           49           38
# 2          820          568          165         1884          525
# 3         4682         5355         1625        12125         2596
# 4         1662         1326          373         1819          922
#
#    C24050_008E  C24050_009E  C24050_010E  ...  B23025_005E  B23025_003E  \
# 0        24187        47611       133336  ...        70100       848232
# ...

# %%
dict = {"C24050_002E": "Total Agriculture", 
    "C24050_003E": "Total Construction", 
    "C24050_004E": "Total Manufacturing", 
    "C24050_005E": "Total Wholesale trade", 
    "C24050_006E": "Total Retail trade", 
    "C24050_007E": "Transportation warehousing utilities", 
    "C24050_008E": "Total Information", 
    "C24050_009E": "Total Finance and real estate", 
    "C24050_010E": "Total scientific administrative and waste management services", 
    "C24050_011E": "Total Educational healthcare and social assistance", 
    "C24050_012E": "Total Arts and entertainment", 
    "C24050_013E": "Total Other services", 
    "C24050_014E": "Total Public administration", 
    "C24050_015E": "Total Management business science and arts occupations", 
    "C24050_029E": "Total Service occupations", 
    "C24050_043E": "Total Sales and office occupations", 
    "C24050_057E": "Total Natural resources and maintenance occupations", 
    "C24050_071E": "Total Production, transportation, and material moving occupations", 
    "C02003_002E": "Population of one race Total",
    "C02003_003E": "White", 
    "C02003_004E": "Black or African American", 
    "C02003_005E": "American Indian and Alaska Native", 
    "C02003_006E": "Asian alone", 
    "C02003_007E": "Native Hawaiian and Other Pacific Islander",
    "C02003_008E": "Population of one race Some other race", 
    "B01002_001E": "Median age: Total", 
    "B15003_001E": "ED TOTAL", 
    "B15003_002E": "ED No schooling completed",
    "B15003_003E": "ED Nursery school",
    "B15003_004E": "ED Kindergarten",
    "B15003_005E": "ED 1st grade",
     "B15003_006E": "ED 2nd grade",
     "B15003_007E": "ED 3rd grade",
     "B15003_008E": "ED 4th grade",
     "B15003_009E": "ED 5th grade",
     "B15003_010E": "ED 6th grade",
     "B15003_011E": "ED 7th grade",
     "B15003_012E": "ED 8th grade",
     "B15003_013E": "ED 9th grade",
     "B15003_014E": "E 10th grade",
     "B15003_015E": "ED 11th grade",
     "B15003_016E": "ED 12th grade no diploma",
    "B19326_001E": "Median income", 
 "B23025_005E": "UNEMPLOYED POP 16 YEARS AND OVER",
 "B23025_003E":  "In civilian labor force",
 "B27010_017E": "Under 19 No health insurance coverage",
 "B27010_033E": "19 to 34 years No health insurance coverage",
 "B27010_050E": "35 to 64 years No health insurance coverage",
 "B27010_001E": "health insurance total",
 "B27010_066E": "65 years and over No health insurance coverage",
    "B01003_001E": "TOTAL POPULATION Estimate"}

# %%
df2015.rename(columns=dict,
          inplace=True)

# %%
df2015
# Out:
#                                             Unnamed: 0  Total Agriculture  \
# 0    Alameda County, California: Summary level: 050...               3308
# 1    Alpine County, California: Summary level: 050,...                  0
# 2    Amador County, California: Summary level: 050,...                195
# 3    Butte County, California: Summary level: 050, ...               3249
# 4    Calaveras County, California: Summary level: 0...                496
# ..                                                 ...                ...
# 560  Wood County, Texas: Summary level: 050, state:...                707
# 561  Yoakum County, Texas: Summary level: 050, stat...               1190
# 562  Young County, Texas: Summary level: 050, state...               1226
# 563  Zapata County, Texas: Summary level: 050, stat...               1006
# 564  Zavala County, Texas: Summary level: 050, stat...                512
#
#      Total Construction  Total Manufacturing  Total Wholesale trade  \
# ...

# %%
df2015.columns = df2015.columns.str.lower()
df2015.columns = df2015.columns.str.replace(' ', "_")
df2015.head()
# Out:
#                                           unnamed:_0  total_agriculture  \
# 0  Alameda County, California: Summary level: 050...               3308
# 1  Alpine County, California: Summary level: 050,...                  0
# 2  Amador County, California: Summary level: 050,...                195
# 3  Butte County, California: Summary level: 050, ...               3249
# 4  Calaveras County, California: Summary level: 0...                496
#
#    total_construction  total_manufacturing  total_wholesale_trade  \
# 0               39861                80961                  20969
# 1                  24                   15                      0
# 2                 820                  568                    165
# 3                4682                 5355                   1625
# 4                1662                 1326                    373
#
#    total_retail_trade  transportation_warehousing_utilities  \
# 0               75187                                 39042
# ...

# %%
df2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 565 entries, 0 to 564
# Data columns (total 54 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   unnamed:_0                                                         565 non-null    object
#  1   total_agriculture                                                  565 non-null    int64
#  2   total_construction                                                 565 non-null    int64
#  3   total_manufacturing                                                565 non-null    int64
#  4   total_wholesale_trade                                              565 non-null    int64
#  5   total_retail_trade                                                 565 non-null    int64
#  6   transportation_warehousing_utilities                               565 non-null    int64
# ...

# %%
df2019 = pd.read_csv('../../cece_data/county_cece_data_2019.csv')

# %%
df2019.county_fip.value_counts()
# Out:
# 1      5
# 89     5
# 65     5
# 67     5
# 69     5
#       ..
# 327    1
# 325    1
# 323    1
# 321    1
# 253    1
# Name: county_fip, Length: 255, dtype: int64

# %%
df2019.rename(columns=dict,
          inplace=True)

# %%
df2019.columns = df2019.columns.str.lower()
df2019.columns = df2019.columns.str.replace(' ', "_")
df2019.head()
# Out:
#                                           unnamed:_0  total_agriculture  \
# 0  Alameda County, California: Summary level: 050...               3129
# 1  Alpine County, California: Summary level: 050,...                 26
# 2  Amador County, California: Summary level: 050,...                702
# 3  Butte County, California: Summary level: 050, ...               3874
# 4  Calaveras County, California: Summary level: 0...                582
#
#    total_construction  total_manufacturing  total_wholesale_trade  \
# 0               45984                84548                  21494
# 1                  23                    9                      0
# 2                1069                  587                    155
# 3                5785                 6529                   1728
# 4                1856                 1463                    397
#
#    total_retail_trade  transportation_warehousing_utilities  \
# 0               76483                                 44172
# ...

# %%
df2019['county_fip'] = df2019.county_fip.astype(str).str.zfill(3)
df2019['state_fip'] = df2019.state_fip.astype(str).str.zfill(2)
df2019.head()
# Out:
#                                           unnamed:_0  total_agriculture  \
# 0  Alameda County, California: Summary level: 050...               3129
# 1  Alpine County, California: Summary level: 050,...                 26
# 2  Amador County, California: Summary level: 050,...                702
# 3  Butte County, California: Summary level: 050, ...               3874
# 4  Calaveras County, California: Summary level: 0...                582
#
#    total_construction  total_manufacturing  total_wholesale_trade  \
# 0               45984                84548                  21494
# 1                  23                    9                      0
# 2                1069                  587                    155
# 3                5785                 6529                   1728
# 4                1856                 1463                    397
#
#    total_retail_trade  transportation_warehousing_utilities  \
# 0               76483                                 44172
# ...

# %%
df2015['county_fip'] = df2015.county_fip.astype(str).str.zfill(3)
df2015['state_fip'] = df2015.state_fip.astype(str).str.zfill(2)
df2015.head()
# Out:
#                                           unnamed:_0  total_agriculture  \
# 0  Alameda County, California: Summary level: 050...               3308
# 1  Alpine County, California: Summary level: 050,...                  0
# 2  Amador County, California: Summary level: 050,...                195
# 3  Butte County, California: Summary level: 050, ...               3249
# 4  Calaveras County, California: Summary level: 0...                496
#
#    total_construction  total_manufacturing  total_wholesale_trade  \
# 0               39861                80961                  20969
# 1                  24                   15                      0
# 2                 820                  568                    165
# 3                4682                 5355                   1625
# 4                1662                 1326                    373
#
#    total_retail_trade  transportation_warehousing_utilities  \
# 0               75187                                 39042
# ...

# %%
df2015.to_csv('../../cece_data/df2015.csv')

# %%
df2019.to_csv('../../cece_data/df2019.csv')

# %%
notMI = df2015.loc[(df2015['state_fip'] == '26')]

# %%
notMI
# Out:
#                                             unnamed:_0  total_agriculture  \
# 228  Alcona County, Michigan: Summary level: 050, s...                 89
# 229  Alger County, Michigan: Summary level: 050, st...                128
# 230  Allegan County, Michigan: Summary level: 050, ...               1775
# 231  Alpena County, Michigan: Summary level: 050, s...                366
# 232  Antrim County, Michigan: Summary level: 050, s...                320
# ..                                                 ...                ...
# 306  Tuscola County, Michigan: Summary level: 050, ...                979
# 307  Van Buren County, Michigan: Summary level: 050...               1507
# 308  Washtenaw County, Michigan: Summary level: 050...                901
# 309  Wayne County, Michigan: Summary level: 050, st...               1929
# 310  Wexford County, Michigan: Summary level: 050, ...                339
#
#      total_construction  total_manufacturing  total_wholesale_trade  \
# ...

# %%
565-83
# Out:
# 482

# %%
pd.read_csv('../../cece_data/df1516features.csv')
# Out:
#      Unnamed: 0  vax_percentage  total_agriculture  total_construction  \
# 0             0        0.962155               3308               39861
# 1             1        0.870878                195                 820
# 2             2        0.902701               3249                4682
# 3             3        0.884900                496                1662
# 4             4        0.997456               2425                 356
# ..          ...             ...                ...                 ...
# 474         474        1.000000                 56                  32
# 475         475        0.928550                103                  33
# 476         476        0.981100                287                 204
# 477         477        1.000000                195                  57
# 478         478        0.996300               1006                 463
#
#      total_manufacturing  total_wholesale_trade  total_retail_trade  \
# ...

# %%
final2016 = pd.read_csv('../../cece_data/df1516final.csv')
final2020 = pd.read_csv('../../cece_data/df1920final.csv')

# %%
final2016.head(2).equals(final2020.head(2))
# Out:
# True

# %%
cen2015 = pd.read_csv('../../cece_data/county_cece_data_2015.csv')
cen2019 = pd.read_csv('../../cece_data/county_cece_data_2019.csv')

# %%
cen2015.state_fip = cen2015.state_fip.astype(str).str.zfill(2)
cen2015.county_fip = cen2015.county_fip.astype(str).str.zfill(3)

cen2019.state_fip = cen2019.state_fip.astype(str).str.zfill(2)
cen2019.county_fip = cen2019.county_fip.astype(str).str.zfill(3)

cen2015['fip'] = cen2015.state_fip + cen2015.county_fip
cen2019['fip'] = cen2019.state_fip + cen2019.county_fip

# %%
targets = pd.read_csv('../../cece_data/targets.csv')

# %%
targets['fip'] = targets.FIPS_x.astype(int).astype(str)

# %%
targets = targets.drop(['FIPS_x', 'FIPS_y'], axis = 1)

# %%
cen2015_target = targets[['target_2016', 'fip']].merge(cen2015, on='fip')
cen2019_target = targets[['target_2020', 'fip']].merge(cen2019, on='fip')

# %%
flipped = pd.read_csv('../../cece_data/flipped.csv')

# %%
flipped
# Out:
#      FIPS_x state      county  target_2016   FIPS_y  target_2020
# 0    6007.0    CA       BUTTE            1   6007.0            0
# 1    6027.0    CA        INYO            1   6027.0            0
# 2   12031.0    FL       DUVAL            1  12031.0            0
# 3   12103.0    FL    PINELLAS            1  12103.0            0
# 4   12117.0    FL    SEMINOLE            1  12117.0            0
# 5   17093.0    IL     KENDALL            1  17093.0            0
# 6   17113.0    IL      MCLEAN            1  17113.0            0
# 7   26081.0    MI        KENT            1  26081.0            0
# 8   26089.0    MI    LEELANAU            1  26089.0            0
# 9   26145.0    MI     SAGINAW            1  26145.0            0
# 10  48163.0    TX        FRIO            0  48163.0            1
# 11  48209.0    TX        HAYS            1  48209.0            0
# 12  48249.0    TX   JIM WELLS            0  48249.0            1
# ...

# %%
cen2015_target.to_csv('../../cece_data/cen2015_target.csv')
cen2015_target
# Out:
#      target_2016    fip                                         Unnamed: 0  \
# 0              0  12001  Alachua County, Florida: Summary level: 050, s...
# 1              1  12003  Baker County, Florida: Summary level: 050, sta...
# 2              1  12005  Bay County, Florida: Summary level: 050, state...
# 3              1  12007  Bradford County, Florida: Summary level: 050, ...
# 4              1  12009  Brevard County, Florida: Summary level: 050, s...
# ..           ...    ...                                                ...
# 502            1  48499  Wood County, Texas: Summary level: 050, state:...
# 503            1  48501  Yoakum County, Texas: Summary level: 050, stat...
# 504            1  48503  Young County, Texas: Summary level: 050, state...
# 505            0  48505  Zapata County, Texas: Summary level: 050, stat...
# 506            0  48507  Zavala County, Texas: Summary level: 050, stat...
#
# ...

# %%
cen2019_target.to_csv('../../cece_data/cen2019_target.csv')
cen2019_target
# Out:
#      target_2020    fip                                         Unnamed: 0  \
# 0              0  12001  Alachua County, Florida: Summary level: 050, s...
# 1              1  12003  Baker County, Florida: Summary level: 050, sta...
# 2              1  12005  Bay County, Florida: Summary level: 050, state...
# 3              1  12007  Bradford County, Florida: Summary level: 050, ...
# 4              1  12009  Brevard County, Florida: Summary level: 050, s...
# ..           ...    ...                                                ...
# 502            1  48499  Wood County, Texas: Summary level: 050, state:...
# 503            1  48501  Yoakum County, Texas: Summary level: 050, stat...
# 504            1  48503  Young County, Texas: Summary level: 050, state...
# 505            1  48505  Zapata County, Texas: Summary level: 050, stat...
# 506            0  48507  Zavala County, Texas: Summary level: 050, stat...
#
# ...
