# %%
import pandas as pd

# %%
dfvax = pd.read_csv('COVID-19_Vaccinations_in_the_United_States_County.csv')
# Out:
# /Users/clementinelacey/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (23,24,25,26) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
dfvax
# Out:
#               Date   FIPS  MMWR_week        Recip_County Recip_State  \
# 0       07/13/2021  24043         28   Washington County          MD
# 1       07/13/2021  46075         28        Jones County          SD
# 2       07/13/2021  13287         28       Turner County          GA
# 3       07/13/2021  18005         28  Bartholomew County          IN
# 4       07/13/2021  18041         28      Fayette County          IN
# ...            ...    ...        ...                 ...         ...
# 698819  12/13/2020  48041         51       Brazos County          TX
# 698820  12/13/2020  20079         51       Harvey County          KS
# 698821  12/13/2020  55017         51     Chippewa County          WI
# 698822  12/13/2020  48391         51      Refugio County          TX
# 698823  12/13/2020  54075         51   Pocahontas County          WV
#
#         Series_Complete_Pop_Pct  Series_Complete_Yes  Series_Complete_12Plus  \
# ...

# %%
dfvax.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698824 entries, 0 to 698823
# Data columns (total 27 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   Date                                    698824 non-null  object
#  1   FIPS                                    698824 non-null  object
#  2   MMWR_week                               698824 non-null  int64
#  3   Recip_County                            698824 non-null  object
#  4   Recip_State                             698824 non-null  object
#  5   Series_Complete_Pop_Pct                 698824 non-null  float64
#  6   Series_Complete_Yes                     698824 non-null  int64
#  7   Series_Complete_12Plus                  698824 non-null  int64
#  8   Series_Complete_12PlusPop_Pct           698824 non-null  float64
#  9   Series_Complete_18Plus                  698824 non-null  int64
# ...

# %%
dfvax.isna().sum()
# Out:
# Date                                           0
# FIPS                                           0
# MMWR_week                                      0
# Recip_County                                   0
# Recip_State                                    0
# Series_Complete_Pop_Pct                        0
# Series_Complete_Yes                            0
# Series_Complete_12Plus                         0
# Series_Complete_12PlusPop_Pct                  0
# Series_Complete_18Plus                         0
# Series_Complete_18PlusPop_Pct                  0
# Series_Complete_65Plus                         0
# Series_Complete_65PlusPop_Pct                  0
# Completeness_pct                               0
# Administered_Dose1_Recip                       0
# Administered_Dose1_Pop_Pct                     0
# Administered_Dose1_Recip_12Plus                0
# Administered_Dose1_Recip_12PlusPop_Pct         0
# Administered_Dose1_Recip_18Plus                0
# ...

# %%
dfdropvax = dfvax.dropna()

# %%
dfdropvax
# Out:
#               Date   FIPS  MMWR_week        Recip_County Recip_State  \
# 0       07/13/2021  24043         28   Washington County          MD
# 1       07/13/2021  46075         28        Jones County          SD
# 2       07/13/2021  13287         28       Turner County          GA
# 3       07/13/2021  18005         28  Bartholomew County          IN
# 4       07/13/2021  18041         28      Fayette County          IN
# ...            ...    ...        ...                 ...         ...
# 657409  12/25/2020  39015         52        Brown County          OH
# 658849  12/25/2020  06037         52  Los Angeles County          CA
# 660131  12/24/2020  22103         52  St. Tammany Parish          LA
# 660193  12/24/2020  39015         52        Brown County          OH
# 664703  12/23/2020  39015         52        Brown County          OH
#
#         Series_Complete_Pop_Pct  Series_Complete_Yes  Series_Complete_12Plus  \
# ...

# %%
dfvote = pd.read_csv("countypres_2000-2020.csv")

# %%
dfvote
# Out:
#        year    state state_po county_name  county_fips        office  \
# 0      2000  ALABAMA       AL     AUTAUGA       1001.0     PRESIDENT
# 1      2000  ALABAMA       AL     AUTAUGA       1001.0     PRESIDENT
# 2      2000  ALABAMA       AL     AUTAUGA       1001.0     PRESIDENT
# 3      2000  ALABAMA       AL     AUTAUGA       1001.0     PRESIDENT
# 4      2000  ALABAMA       AL     BALDWIN       1003.0     PRESIDENT
# ...     ...      ...      ...         ...          ...           ...
# 72612  2020  WYOMING       WY    WASHAKIE      56043.0  US PRESIDENT
# 72613  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 72614  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 72615  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 72616  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
#
#                candidate        party  candidatevotes  totalvotes   version  \
# ...
