# %%
import pandas as pd

# %%
df2020 = pd.read_csv('../../data/pres2020.csv')

# %%
df2020
# Out:
#      Unnamed: 0  year     FIPS     office state  dem_votes  rep_votes  \
# 0             5  2020   6001.0  PRESIDENT    CA   617659.0   136309.0
# 1            11  2020   6003.0  PRESIDENT    CA      476.0      244.0
# 2            17  2020   6005.0  PRESIDENT    CA     8153.0    13585.0
# 3            23  2020   6007.0  PRESIDENT    CA    50426.0    48730.0
# 4            29  2020   6009.0  PRESIDENT    CA    10046.0    16518.0
# ..          ...   ...      ...        ...   ...        ...        ...
# 475        2860  2020  48499.0  PRESIDENT    TX     3509.0    19049.0
# 476        2866  2020  48501.0  PRESIDENT    TX      420.0     2174.0
# 477        2872  2020  48503.0  PRESIDENT    TX     1034.0     7110.0
# 478        2878  2020  48505.0  PRESIDENT    TX     1826.0     2033.0
# 479        2884  2020  48507.0  PRESIDENT    TX     2864.0     1490.0
#
#      total_votes  target  win_percentage  win_margin  Population(2010)  \
# ...

# %%
df2020votes = df2020[['FIPS', 'target']]

# %%
df2020votes
# Out:
#         FIPS  target
# 0     6001.0       0
# 1     6003.0       0
# 2     6005.0       1
# 3     6007.0       0
# 4     6009.0       1
# ..       ...     ...
# 475  48499.0       1
# 476  48501.0       1
# 477  48503.0       1
# 478  48505.0       1
# 479  48507.0       0
#
# [480 rows x 2 columns]

# %%
df = pd.read_csv('../../data/1620_skew_diff.csv')

# %%
df
# Out:
#       Unnamed: 0  all_skew_diff  1620_skew_diff     FIPS      county state  \
# 0           2764         22.275           43.02  49031.0       PIUTE    UT
# 1           2755         22.955           41.68  49013.0    DUCHESNE    UT
# 2           2772         22.465           40.79  49047.0      UINTAH    UT
# 3           2769         21.885           40.65  49041.0      SEVIER    UT
# 4           2756         22.395           40.01  49015.0       EMERY    UT
# ...          ...            ...             ...      ...         ...   ...
# 3110        1460         13.300            0.01  29009.0       BARRY    MO
# 3111         203          9.020            0.01   6087.0  SANTA CRUZ    CA
# 3112        2014         12.710            0.01  38103.0       WELLS    ND
# 3113         871         16.005            0.00  20021.0    CHEROKEE    KS
# 3114         994         10.185            0.00  21057.0  CUMBERLAND    KY
#
#       Population(2010)  Latitude  Longitude
# ...

# %%
flipped = pd.read_csv('../../data/flipped.csv')

# %%
flipped
# Out:
#      FIPS_x state      county  target_2016   FIPS_y  target_2020
# 0    6007.0    CA       BUTTE            1   6007.0            0
# 1    6027.0    CA        INYO            1   6027.0            0
# 2   12031.0    FL       DUVAL            1  12031.0            0
# 3   12103.0    FL    PINELLAS            1  12103.0            0
# 4   12117.0    FL    SEMINOLE            1  12117.0            0
# 5   17093.0    IL     KENDALL            1  17093.0            0
# 6   17113.0    IL      MCLEAN            1  17113.0            0
# 7   26081.0    MI        KENT            1  26081.0            0
# 8   26089.0    MI    LEELANAU            1  26089.0            0
# 9   26145.0    MI     SAGINAW            1  26145.0            0
# 10  48163.0    TX        FRIO            0  48163.0            1
# 11  48209.0    TX        HAYS            1  48209.0            0
# 12  48249.0    TX   JIM WELLS            0  48249.0            1
# ...
