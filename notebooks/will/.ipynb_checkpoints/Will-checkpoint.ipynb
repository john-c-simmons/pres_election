# %%
import pandas as pd

# %%
election_url = "../../data/countypres_2000-2020.csv"

# %%
elec = pd.read_csv(election_url)

# %%
vaccine_url = "../../data/COVID-19_Vaccinations_in_the_United_States_County.csv"

# %%
vacc = pd.read_csv(vaccine_url)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (23,24,25,26) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
geo_url = "../../data/geo.csv"

# %%
geo = pd.read_csv(geo_url)

# %%
geo.head(2)
# Out:
#    Sort [1] State  FIPS County [2] County Seat(s) [3] Population(2010)  \
# 0         1    AL  1001    Autauga         Prattville           54,571
# 1         2    AL  1003    Baldwin        Bay Minette          182,265
#
#   Land Areakm² Land Areami² Water Areakm² Water Areami² Total Areakm²  \
# 0    1,539.582      594.436        25.776         9.952     1,565.358
# 1    4,117.522    1,589.784     1,133.190       437.527     5,250.712
#
#   Total Areami²     Latitude    Longitude
# 0       604.388  +32.536382°  –86.644490°
# 1     2,027.311  +30.659218°  –87.746067°

# %%
vacc.head(2)
# Out:
#          Date   FIPS  MMWR_week                  Recip_County Recip_State  \
# 0  07/16/2021  02090         28  Fairbanks North Star Borough          AK
# 1  07/16/2021    UNK         28                Unknown County          KS
#
#    Series_Complete_Pop_Pct  Series_Complete_Yes  Series_Complete_12Plus  \
# 0                     40.7                39453                   39366
# 1                      0.0                84341                   84336
#
#    Series_Complete_12PlusPop_Pct  Series_Complete_18Plus  ...  \
# 0                           48.9                   37459  ...
# 1                            0.0                   82542  ...
#
#    Administered_Dose1_Recip_12PlusPop_Pct  Administered_Dose1_Recip_18Plus  \
# 0                                    55.4                          42396.0
# 1                                     0.0                         108681.0
#
#    Administered_Dose1_Recip_18PlusPop_Pct  Administered_Dose1_Recip_65Plus  \
# 0                                    57.4                           8135.0
# 1                                     0.0                          32178.0
#
#    Administered_Dose1_Recip_65PlusPop_Pct  SVI_CTGY  \
# 0                                    75.1   Low-Mod
# 1                                     0.0       NaN
#
#    Series_Complete_Pop_Pct_SVI  Series_Complete_12PlusPop_Pct_SVI  \
# 0      Mod-High VC/Low-Mod SVI            Mod-High VC/Low-Mod SVI
# 1                          NaN                                NaN
#
#    Series_Complete_18PlusPop_Pct_SVI  Series_Complete_65PlusPop_Pct_SVI
# 0                High VC/Low-Mod SVI                High VC/Low-Mod SVI
# 1                                NaN                                NaN
#
# [2 rows x 27 columns]

# %%
elec.head(2)
# Out:
#    year    state state_po county_name  county_fips     office       candidate  \
# 0  2000  ALABAMA       AL     AUTAUGA       1001.0  PRESIDENT         AL GORE
# 1  2000  ALABAMA       AL     AUTAUGA       1001.0  PRESIDENT  GEORGE W. BUSH
#
#         party  candidatevotes  totalvotes   version   mode
# 0    DEMOCRAT          4942.0     17208.0  20191203  TOTAL
# 1  REPUBLICAN         11993.0     17208.0  20191203  TOTAL

# %%
elec[(elec["state_po"]== "AL") & (elec["county_name"]== "JEFFERSON") & (elec["year"]==2020)]
# Out:
#        year    state state_po county_name  county_fips     office  \
# 50632  2020  ALABAMA       AL   JEFFERSON       1073.0  PRESIDENT
# 50633  2020  ALABAMA       AL   JEFFERSON       1073.0  PRESIDENT
# 50634  2020  ALABAMA       AL   JEFFERSON       1073.0  PRESIDENT
#
#                candidate       party  candidatevotes  totalvotes   version  \
# 50632  JOSEPH R BIDEN JR    DEMOCRAT        181688.0    325848.0  20210622
# 50633              OTHER       OTHER          5317.0    325848.0  20210622
# 50634     DONALD J TRUMP  REPUBLICAN        138843.0    325848.0  20210622
#
#         mode
# 50632  TOTAL
# 50633  TOTAL
# 50634  TOTAL

# %%
vacc[(vacc["Recip_State"] == "AL") & (vacc["Recip_County"] == "Jefferson County") & (vacc["Date"].str[-4:]=="2020")].head(2)
# Out:
#               Date   FIPS  MMWR_week      Recip_County Recip_State  \
# 649375  12/31/2020  01073         53  Jefferson County          AL
# 651194  12/30/2020  01073         53  Jefferson County          AL
#
#         Series_Complete_Pop_Pct  Series_Complete_Yes  Series_Complete_12Plus  \
# 649375                      0.0                    0                       0
# 651194                      0.0                    0                       0
#
#         Series_Complete_12PlusPop_Pct  Series_Complete_18Plus  ...  \
# 649375                            0.0                       0  ...
# 651194                            0.0                       0  ...
#
#         Administered_Dose1_Recip_12PlusPop_Pct  \
# 649375                                     0.0
# 651194                                     0.0
#
#         Administered_Dose1_Recip_18Plus  \
# 649375                              NaN
# 651194                              NaN
#
#         Administered_Dose1_Recip_18PlusPop_Pct  \
# 649375                                     0.0
# 651194                                     0.0
#
#         Administered_Dose1_Recip_65Plus  \
# 649375                              NaN
# 651194                              NaN
#
#         Administered_Dose1_Recip_65PlusPop_Pct  SVI_CTGY  \
# 649375                                     0.0  Mod-High
# 651194                                     0.0  Mod-High
#
#         Series_Complete_Pop_Pct_SVI  Series_Complete_12PlusPop_Pct_SVI  \
# 649375                          NaN                                NaN
# 651194                          NaN                                NaN
#
#         Series_Complete_18PlusPop_Pct_SVI  Series_Complete_65PlusPop_Pct_SVI
# 649375                                NaN                                NaN
# 651194                                NaN                                NaN
#
# [2 rows x 27 columns]

# %%
#geo cleanup
geo.replace(',','', regex=True, inplace=True)
geo["Longitude"] = geo["Longitude"].map(lambda l: float(l[1: -2])*-1 if l[0] == "–" else float(l[1: -2]))
geo["Latitude"] = geo["Latitude"].map(lambda l: float(l[1: -2])*-1 if l[0] == "–" else float(l[1: -2]))
geo.drop(["Land Areakm²", "Total Areakm²", "Water Areakm²", "County Seat(s) [3]", "Sort [1]"], axis=1, inplace=True)
geo_clean["FIPS"] = geo_clean['FIPS'].map(lambda x: int("0" + str(x)))
geo_clean = geo

# %%
geo_clean.head()
# Out:
#   State    FIPS County [2] Population(2010) Land Areami² Water Areami²  \
# 0    AL  100112    Autauga            54571      594.436         9.952
# 1    AL  100312    Baldwin           182265     1589.784       437.527
# 2    AL  100512    Barbour            27457      884.876        19.639
# 3    AL  100712       Bibb            22915      622.582         3.587
# 4    AL  100912     Blount            57322      644.776         5.852
#
#   Total Areami²  Latitude  Longitude
# 0       604.388  32.53638  -86.64449
# 1      2027.311  30.65921  -87.74606
# 2       904.515  31.87067  -85.40545
# 3       626.169  33.01589  -87.12714
# 4       650.628  33.97744  -86.56724

# %%
geo_clean.shape
# Out:
# (3143, 9)
